# %%
from docling.document_converter import DocumentConverter

source = "https://arxiv.org/pdf/2408.09869"  # document per local path or URL
# converter = DocumentConverter()
# result = converter.convert(source)
# print(result.document.export_to_markdown())  # output: "## Docling Technical Report[...]"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from docling.document_converter import DocumentConverter
#       3 # source = "https://arxiv.org/pdf/2408.09869"  # document per local path or URL
#       4 # converter = DocumentConverter()
#       5 # result = converter.convert(source)
#       6 # print(result.document.export_to_markdown())  # output: "## Docling Technical Report[...]"
#
# File ~/Workspace/development/python_studies/.venv/lib/python3.11/site-packages/docling/document_converter.py:35
#      33 from docling.pipeline.base_pipeline import BasePipeline
#      34 from docling.pipeline.simple_pipeline import SimplePipeline
# ---> 35 from docling.pipeline.standard_pdf_pipeline import StandardPdfPipeline
#      36 from docling.utils.utils import chunkify
#      38 _log = logging.getLogger(__name__)
#
# File ~/Workspace/development/python_studies/.venv/lib/python3.11/site-packages/docling/pipeline/standard_pdf_pipeline.py:23
#      21 from docling.models.ds_glm_model import GlmModel, GlmOptions
#      22 from docling.models.easyocr_model import EasyOcrModel
# ---> 23 from docling.models.layout_model import LayoutModel
#      24 from docling.models.ocr_mac_model import OcrMacModel
#      25 from docling.models.page_assemble_model import PageAssembleModel, PageAssembleOptions
#
# File ~/Workspace/development/python_studies/.venv/lib/python3.11/site-packages/docling/models/layout_model.py:9
#       6 from typing import Iterable, List
#       8 from docling_core.types.doc import CoordOrigin, DocItemLabel
# ----> 9 from docling_ibm_models.layoutmodel.layout_predictor import LayoutPredictor
#      10 from PIL import ImageDraw
#      12 from docling.datamodel.base_models import (
#      13     BoundingBox,
#      14     Cell,
#    (...)
#      17     Page,
#      18 )
#
# File ~/Workspace/development/python_studies/.venv/lib/python3.11/site-packages/docling_ibm_models/layoutmodel/layout_predictor.py:11
#       9 import numpy as np
#      10 import torch
# ---> 11 import torchvision.transforms as T
#      12 from PIL import Image
#      14 MODEL_CHECKPOINT_FN = "model.pt"
#
# File ~/Workspace/development/python_studies/.venv/lib/python3.11/site-packages/torchvision/__init__.py:10
#       7 # Don't re-order these, we need to load the _C extension (done when importing
#       8 # .extensions) before entering _meta_registrations.
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#      13     from .version import __version__  # noqa: F401
#
# File ~/Workspace/development/python_studies/.venv/lib/python3.11/site-packages/torchvision/datasets/__init__.py:1
# ----> 1 from ._optical_flow import FlyingChairs, FlyingThings3D, HD1K, KittiFlow, Sintel
#       2 from ._stereo_matching import (
#       3     CarlaStereo,
#       4     CREStereo,
#    (...)
#      12     SintelStereo,
#      13 )
#      14 from .caltech import Caltech101, Caltech256
#
# File ~/Workspace/development/python_studies/.venv/lib/python3.11/site-packages/torchvision/datasets/_optical_flow.py:13
#      10 from PIL import Image
#      12 from ..io.image import decode_png, read_file
# ---> 13 from .utils import _read_pfm, verify_str_arg
#      14 from .vision import VisionDataset
#      16 T1 = Tuple[Image.Image, Image.Image, Optional[np.ndarray], Optional[np.ndarray]]
#
# File ~/Workspace/development/python_studies/.venv/lib/python3.11/site-packages/torchvision/datasets/utils.py:4
#       2 import gzip
#       3 import hashlib
# ----> 4 import lzma
#       5 import os
#       6 import os.path
#
# File ~/Workspace/bin/.pyenv/versions/3.11.1/lib/python3.11/lzma.py:27
#      25 import io
#      26 import os
# ---> 27 from _lzma import *
#      28 from _lzma import _encode_filter_properties, _decode_filter_properties
#      29 import _compression
#
# ModuleNotFoundError: No module named '_lzma'
